# %% [markdown]
# <a href="https://colab.research.google.com/github/Maoelan/1918008_Maulana-Muhammad_Comvis_Feature-Extraction/blob/main/1918008_Maulana_Muhammad_%7C_Cat_and_Dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Menginstall kaggle
# !pip install -q kaggle

# %%
#Upload file kaggle.json
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fbf09999-c091-42e0-9d1f-ef34ae460687" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbf09999-c091-42e0-9d1f-ef34ae460687">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"maoel31","key":"7bb6c5962ce8666cb65272c4f9031d78"}'}

# %%
#Membuat folder kaggle di google drive
! mkdir ~/.kaggle

# %%
#Mengcopy kaggle.json ke folder kaggle
! cp kaggle.json ~/.kaggle/

# %%
#Permission untuk menggunakan json
! chmod 600 ~/.kaggle/kaggle.json

# %%
#Untuk melihat list dataset yang ada dikaggle
! kaggle datasets list
# Out:
# ref                                                            title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# datasets/piterfm/2022-ukraine-russian-war                      2022 Ukraine Russia War                            2KB  2022-04-14 11:06:51           8095        460  1.0
# datasets/kamilpytlak/personal-key-indicators-of-heart-disease  Personal Key Indicators of Heart Disease           3MB  2022-02-16 10:18:03          13342        291  1.0
# datasets/ankanhore545/cost-of-living-index-2022                Cost of Living Index 2022                          4KB  2022-04-09 06:22:10           2645         50  0.8235294
# ...

# %%
#Untuk mendownload dataset cat and dog di kaggle
! kaggle datasets download -d tongpython/cat-and-dog
# Out:
# ...
#  90% 197M/218M [00:00<00:00, 236MB/s]
# 100% 218M/218M [00:00<00:00, 253MB/s]

# %%
#Untuk mengekstrak dataset cat-and-dog.zip
! unzip cat-and-dog.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: training_set/training_set/cats/cat.3704.jpg
#   inflating: training_set/training_set/cats/cat.3705.jpg
#   inflating: training_set/training_set/cats/cat.3706.jpg
#   inflating: training_set/training_set/cats/cat.3707.jpg
#   inflating: training_set/training_set/cats/cat.3708.jpg
#   inflating: training_set/training_set/cats/cat.3709.jpg
#   inflating: training_set/training_set/cats/cat.371.jpg
#   inflating: training_set/training_set/cats/cat.3710.jpg
#   inflating: training_set/training_set/cats/cat.3711.jpg
#   inflating: training_set/training_set/cats/cat.3712.jpg
#   inflating: training_set/training_set/cats/cat.3713.jpg
#   inflating: training_set/training_set/cats/cat.3714.jpg
#   inflating: training_set/training_set/cats/cat.3715.jpg
#   inflating: training_set/training_set/cats/cat.3716.jpg
#   inflating: training_set/training_set/cats/cat.3717.jpg
#   inflating: training_set/training_set/cats/cat.3718.jpg
# ...

# %%
#Memasukkan library yang dibutuhkan
from os import listdir
import tensorflow as tf
import keras
import cv2
import matplotlib.pyplot as plt
import numpy as np
from keras.models import load_model
import keras.layers as L

# %%
#Menampilkan citra asli
plt.figure(figsize=(9,6))
for id, img in enumerate(listdir('../content/training_set/training_set/cats/kucing')[0:3]):
    img = cv2.imread('../content/training_set/training_set/cats/kucing/'+img)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.subplot(2,3,id+1)
    plt.imshow(img)
for id, img in enumerate(listdir('../content/training_set/training_set/dogs/anjing')[0:3]):
    img = cv2.imread('../content/training_set/training_set/dogs/anjing/'+img)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.subplot(2,3,id+4)
    plt.imshow(img)

# %%
#Mengubah citra ke grayscale
plt.figure(figsize=(9,6))
for id, img in enumerate(listdir('../content/training_set/training_set/cats/kucing')[0:3]):
    img = cv2.imread('../content/training_set/training_set/cats/kucing/'+img)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.subplot(2,3,id+1)
    plt.imshow(img)
for id, img in enumerate(listdir('../content/training_set/training_set/dogs/anjing')[0:3]):
    img = cv2.imread('../content/training_set/training_set/dogs/anjing/'+img)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.subplot(2,3,id+4)
    plt.imshow(img)

# %%
len_train_set = len(listdir('../content/training_set/training_set/dogs/anjing'))+len(listdir('../content/training_set/training_set/cats/kucing/'))
len_test_set = len(listdir('../content/training_set/training_set/dogs/anjing'))+len(listdir('../content/training_set/training_set/cats/kucing/'))

# %%
print(f'length of test set:{len_test_set}')
print(f'length of training set:{len_train_set}')
# Out:
# length of test set:6
# length of training set:6
